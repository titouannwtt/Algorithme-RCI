# %%
# Out:
# Collecting pathlib
#   Downloading pathlib-1.0.1.tar.gz (49 kB)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\gam\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\gam\\AppData\\Local\\Temp\\pip-install-aymzp1r5\\pathlib\\setup.py'"'"'; __file__='"'"'C:\\Users\\gam\\AppData\\Local\\Temp\\pip-install-aymzp1r5\\pathlib\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\gam\AppData\Local\Temp\pip-pip-egg-info-jg4bu9g8'
#          cwd: C:\Users\gam\AppData\Local\Temp\pip-install-aymzp1r5\pathlib\
#     Complete output (19 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\gam\AppData\Local\Temp\pip-install-aymzp1r5\pathlib\setup.py", line 6, in <module>
#         setup(
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 109, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\dist.py", line 460, in __init__
#         for ep in metadata.entry_points(group='distutils.setup_keywords'):
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 999, in entry_points
#         return SelectableGroups.load(eps).select(**params)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 449, in load
#         ordered = sorted(eps, key=by_group)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 997, in <genexpr>
#         dist.entry_points for dist in unique(distributions())
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 609, in entry_points
#         return EntryPoints._from_text_for(self.read_text('entry_points.txt'), self)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 917, in read_text
#         return self._path.joinpath(filename).read_text(encoding='utf-8')
#     AttributeError: 'WindowsPath' object has no attribute 'read_text'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
pip install ccxt
# Out:
# Requirement already satisfied: ccxt in c:\users\gam\anaconda3\lib\site-packages (1.77.62)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (3.1.1)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (61.2.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (2.24.0)
# Requirement already satisfied: aiodns>=1.1.1; python_version >= "3.5.2" in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (3.0.0)
# Requirement already satisfied: aiohttp>=3.8; python_version >= "3.5.2" in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (3.8.1)
# Requirement already satisfied: yarl==1.7.2; python_version >= "3.5.2" in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (1.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (2020.6.20)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\gam\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.14.3)
# Requirement already satisfied: six>=1.4.1 in c:\users\gam\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gam\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gam\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gam\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (2.10)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\gam\anaconda3\lib\site-packages (from aiodns>=1.1.1; python_version >= "3.5.2"->ccxt) (4.1.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (20.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (5.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (2.0.12)
# Requirement already satisfied: pycparser in c:\users\gam\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.6.1->ccxt) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append( 'C:/Users/gam/OneDrive - Groupe ESIEA/Bureau/Bots/backtest-ipynb/utilities')
from data_engine import DataEngine
import pandas as pd
import ccxt
import json
f = open('C:/Users/gam/OneDrive - Groupe ESIEA/Bureau/Bots/backtest-ipynb/database/pair_list.json')
pair_json = json.load(f)
f.close()

# %% [markdown]
# <h1>Inspect data from api or database</h1>

# %%
# -- Data variable --
pair_symbol = 'BTC/USDT'
timeframe = '1w'
start_date = '2017-01-01T00:00:00'

# -- Instance class --
dataEngine = DataEngine(session=ccxt.binance())

# -- Check from exchange API --
df =dataEngine.get_historical_from_api(pair_symbol, timeframe, start_date)

# -- Check from local database --
# df =dataEngine.get_historical_from_db(pair_symbol, timeframe, start_date)

df
# Out:
#                 open      high       low     close         volume
# timestamp
# 2017-08-14   4261.48   4485.39   3850.00   4086.29    2843.431426
# 2017-08-21   4069.13   4453.91   3400.00   4310.01    4599.396629
# 2017-08-28   4310.01   4939.19   4124.54   4509.08    4753.843376
# 2017-09-04   4505.00   4788.59   3603.00   4130.37    6382.787745
# 2017-09-11   4153.62   4394.59   2817.00   3699.99    8106.705127
# ...              ...       ...       ...       ...            ...
# 2022-03-28  46827.76  48189.84  44200.00  46407.35  312053.159640
# 2022-04-04  46407.36  47200.00  41868.00  42158.85  268118.291110
# 2022-04-11  42158.85  42414.71  39200.00  39678.12  259281.048700
# 2022-04-18  39678.11  42976.00  38536.51  39450.13  283885.036370
# 2022-04-25  39450.12  40797.31  38000.18  38329.00  112494.734560
#
# [246 rows x 5 columns]

# %% [markdown]
# <h1>Download data from api to local database</h1>

# %%
# -- Data variable --
pair_symbols = pair_json['all']
#pair_symbols = ['BTC/USDT']

# -- Instance class --
dataEngine = DataEngine(session=ccxt.ftx())

# -- Download data from data variable --
timeframes = ['4h']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

# -- Download data from data variable --
timeframes = ['1h']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

# -- Download data from data variable --
timeframes = ['30m']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

# -- Download data from data variable --
timeframes = ['15m']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

# -- Download data from data variable --
timeframes = ['5m']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

# -- Download data from data variable --
timeframes = ['3m']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

# -- Download data from data variable --
timeframes = ['1m']
start_date = '2020-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)
# Out:
# -> downloding symbol BTC-PERP for timeframe 4h
# BTC-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 4h
# ETH-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 4h
# DOT-PERP 3678 Candles 4h load since the : 2020-08-21 20:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/DOT-PERP.p
# -> downloding symbol LUNA-PERP for timeframe 4h
# LUNA-PERP 2597 Candles 4h load since the : 2021-02-18 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/LUNA-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 4h
# EGLD-PERP 2848 Candles 4h load since the : 2021-01-07 04:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 4h
# AVAX-PERP 3490 Candles 4h load since the : 2020-09-22 04:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 4h
# XRP-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 4h
# MANA-PERP 1353 Candles 4h load since the : 2021-09-13 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 4h
# XTZ-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 4h
# WAVES-PERP 3189 Candles 4h load since the : 2020-11-11 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 4h
# ATOM-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 4h
# MATIC-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 4h
# KSM-PERP 2805 Candles 4h load since the : 2021-01-14 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 4h
# LINK-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 4h
# SHIB-PERP 2108 Candles 4h load since the : 2021-05-10 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 4h
# FTM-PERP 2566 Candles 4h load since the : 2021-02-23 04:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 4h
# NEAR-PERP 2481 Candles 4h load since the : 2021-03-09 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 4h
# SOL-PERP 3833 Candles 4h load since the : 2020-07-27 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 4h
# THETA-PERP 4201 Candles 4h load since the : 2020-05-26 16:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 4h
# CRO-PERP 2391 Candles 4h load since the : 2021-03-24 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 4h
# FTT-PERP 2872 Candles 4h load since the : 2021-01-03 04:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 4h
# RUNE-PERP 3874 Candles 4h load since the : 2020-07-20 04:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 4h
# AAVE-PERP 3371 Candles 4h load since the : 2020-10-12 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 4h
# AXS-PERP 2313 Candles 4h load since the : 2021-04-06 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 4h
# GALA-PERP 953 Candles 4h load since the : 2021-11-19 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 4h
# SAND-PERP 2396 Candles 4h load since the : 2021-03-23 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 4h
# NEO-PERP 3457 Candles 4h load since the : 2020-09-27 16:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 4h
# LTC-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 4h
# LRC-PERP 2469 Candles 4h load since the : 2021-03-11 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 4h
# CAKE-PERP 2475 Candles 4h load since the : 2021-03-10 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 4h
# XLM-PERP 3101 Candles 4h load since the : 2020-11-26 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 4h
# COMP-PERP 4061 Candles 4h load since the : 2020-06-19 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 4h
# SLP-PERP 1730 Candles 4h load since the : 2021-07-12 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 4h
# APE-PERP 242 Candles 4h load since the : 2022-03-17 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 4h
# MTL-PERP 2343 Candles 4h load since the : 2021-04-01 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 4h
# KAVA-PERP 2487 Candles 4h load since the : 2021-03-08 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 4h
# CRV-PERP 2842 Candles 4h load since the : 2021-01-08 04:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 4h
# SNX-PERP 3135 Candles 4h load since the : 2020-11-20 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 4h
# LOOKS-PERP 631 Candles 4h load since the : 2022-01-11 16:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 4h
# XMR-PERP 2879 Candles 4h load since the : 2021-01-02 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 4h
# TRX-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 4h
# ZRX-PERP 2547 Candles 4h load since the : 2021-02-26 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 4h
# PUNDIX-PERP 2324 Candles 4h load since the : 2021-04-04 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 4h
# SUSHI-PERP 3618 Candles 4h load since the : 2020-08-31 20:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 4h
# BCH-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 4h
# BNB-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 4h
# JASMY-PERP 152 Candles 4h load since the : 2022-04-01 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 4h
# ZIL-PERP 2517 Candles 4h load since the : 2021-03-03 08:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 4h
# FIL-PERP 3350 Candles 4h load since the : 2020-10-15 12:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 4h
# ADA-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 4h
# ETC-PERP 5081 Candles 4h load since the : 2020-01-01 00:00:00 to : 2022-04-26 16:00:00 in ../database/FTX/4h/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 1h
# BTC-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 1h
# ETH-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 1h
# DOT-PERP 14711 Candles 1h load since the : 2020-08-21 20:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/DOT-PERP.p
# -> downloding symbol LUNA-PERP for timeframe 1h
# LUNA-PERP 10385 Candles 1h load since the : 2021-02-18 02:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/LUNA-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 1h
# EGLD-PERP 11390 Candles 1h load since the : 2021-01-07 05:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 1h
# AVAX-PERP 13957 Candles 1h load since the : 2020-09-22 06:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 1h
# XRP-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 1h
# MANA-PERP 5409 Candles 1h load since the : 2021-09-13 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 1h
# XTZ-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 1h
# WAVES-PERP 12754 Candles 1h load since the : 2020-11-11 09:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 1h
# ATOM-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 1h
# MATIC-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 1h
# KSM-PERP 11217 Candles 1h load since the : 2021-01-14 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 1h
# LINK-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 1h
# SHIB-PERP 8430 Candles 1h load since the : 2021-05-10 13:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 1h
# FTM-PERP 10263 Candles 1h load since the : 2021-02-23 04:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 1h
# NEAR-PERP 9921 Candles 1h load since the : 2021-03-09 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 1h
# SOL-PERP 15331 Candles 1h load since the : 2020-07-27 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 1h
# THETA-PERP 16803 Candles 1h load since the : 2020-05-26 16:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 1h
# CRO-PERP 9561 Candles 1h load since the : 2021-03-24 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 1h
# FTT-PERP 11486 Candles 1h load since the : 2021-01-03 05:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 1h
# RUNE-PERP 15492 Candles 1h load since the : 2020-07-20 07:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 1h
# AAVE-PERP 13481 Candles 1h load since the : 2020-10-12 02:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 1h
# AXS-PERP 9249 Candles 1h load since the : 2021-04-06 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 1h
# GALA-PERP 3811 Candles 1h load since the : 2021-11-19 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 1h
# SAND-PERP 9583 Candles 1h load since the : 2021-03-23 12:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 1h
# NEO-PERP 13827 Candles 1h load since the : 2020-09-27 16:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 1h
# LTC-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 1h
# LRC-PERP 9874 Candles 1h load since the : 2021-03-11 09:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 1h
# CAKE-PERP 9897 Candles 1h load since the : 2021-03-10 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 1h
# XLM-PERP 12403 Candles 1h load since the : 2020-11-26 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 1h
# COMP-PERP 16241 Candles 1h load since the : 2020-06-19 02:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 1h
# SLP-PERP 6919 Candles 1h load since the : 2021-07-12 12:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 1h
# APE-PERP 967 Candles 1h load since the : 2022-03-17 12:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 1h
# MTL-PERP 9369 Candles 1h load since the : 2021-04-01 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 1h
# KAVA-PERP 9944 Candles 1h load since the : 2021-03-08 11:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 1h
# CRV-PERP 11365 Candles 1h load since the : 2021-01-08 06:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 1h
# SNX-PERP 12537 Candles 1h load since the : 2020-11-20 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 1h
# LOOKS-PERP 2523 Candles 1h load since the : 2022-01-11 16:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 1h
# XMR-PERP 11514 Candles 1h load since the : 2021-01-02 01:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 1h
# TRX-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 1h
# ZRX-PERP 10185 Candles 1h load since the : 2021-02-26 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 1h
# PUNDIX-PERP 9293 Candles 1h load since the : 2021-04-04 14:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 1h
# SUSHI-PERP 14470 Candles 1h load since the : 2020-08-31 21:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 1h
# BCH-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 1h
# BNB-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 1h
# JASMY-PERP 605 Candles 1h load since the : 2022-04-01 14:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 1h
# ZIL-PERP 10065 Candles 1h load since the : 2021-03-03 10:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 1h
# FIL-PERP 13397 Candles 1h load since the : 2020-10-15 14:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 1h
# ADA-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 1h
# ETC-PERP 20323 Candles 1h load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:00:00 in ../database/FTX/1h/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 30m
# Error empty dataframe on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 30m
# Error empty dataframe on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 30m
# Error empty dataframe on DOT-PERP
# -> downloding symbol LUNA-PERP for timeframe 30m
# Error empty dataframe on LUNA-PERP
# -> downloding symbol EGLD-PERP for timeframe 30m
# Error empty dataframe on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 30m
# Error empty dataframe on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 30m
# Error empty dataframe on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 30m
# Error empty dataframe on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 30m
# Error empty dataframe on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 30m
# Error empty dataframe on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 30m
# Error empty dataframe on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 30m
# Error empty dataframe on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 30m
# Error empty dataframe on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 30m
# Error empty dataframe on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 30m
# Error empty dataframe on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 30m
# Error empty dataframe on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 30m
# Error empty dataframe on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 30m
# Error empty dataframe on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 30m
# Error empty dataframe on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 30m
# Error empty dataframe on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 30m
# Error empty dataframe on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 30m
# Error empty dataframe on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 30m
# Error empty dataframe on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 30m
# Error empty dataframe on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 30m
# Error empty dataframe on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 30m
# Error empty dataframe on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 30m
# Error empty dataframe on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 30m
# Error empty dataframe on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 30m
# Error empty dataframe on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 30m
# Error empty dataframe on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 30m
# Error empty dataframe on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 30m
# Error empty dataframe on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 30m
# Error empty dataframe on SLP-PERP
# -> downloding symbol APE-PERP for timeframe 30m
# Error empty dataframe on APE-PERP
# -> downloding symbol MTL-PERP for timeframe 30m
# Error empty dataframe on MTL-PERP
# -> downloding symbol KAVA-PERP for timeframe 30m
# Error empty dataframe on KAVA-PERP
# -> downloding symbol CRV-PERP for timeframe 30m
# Error empty dataframe on CRV-PERP
# -> downloding symbol SNX-PERP for timeframe 30m
# Error empty dataframe on SNX-PERP
# -> downloding symbol LOOKS-PERP for timeframe 30m
# Error empty dataframe on LOOKS-PERP
# -> downloding symbol XMR-PERP for timeframe 30m
# Error empty dataframe on XMR-PERP
# -> downloding symbol TRX-PERP for timeframe 30m
# Error empty dataframe on TRX-PERP
# -> downloding symbol ZRX-PERP for timeframe 30m
# Error empty dataframe on ZRX-PERP
# -> downloding symbol PUNDIX-PERP for timeframe 30m
# Error empty dataframe on PUNDIX-PERP
# -> downloding symbol SUSHI-PERP for timeframe 30m
# Error empty dataframe on SUSHI-PERP
# -> downloding symbol BCH-PERP for timeframe 30m
# Error empty dataframe on BCH-PERP
# -> downloding symbol BNB-PERP for timeframe 30m
# Error empty dataframe on BNB-PERP
# -> downloding symbol JASMY-PERP for timeframe 30m
# Error empty dataframe on JASMY-PERP
# -> downloding symbol ZIL-PERP for timeframe 30m
# Error empty dataframe on ZIL-PERP
# -> downloding symbol FIL-PERP for timeframe 30m
# Error empty dataframe on FIL-PERP
# -> downloding symbol ADA-PERP for timeframe 30m
# Error empty dataframe on ADA-PERP
# -> downloding symbol ETC-PERP for timeframe 30m
# Error empty dataframe on ETC-PERP
# -> downloding symbol BTC-PERP for timeframe 15m
# BTC-PERP 81290 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:30:00 in ../database/FTX/15m/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 15m
# ETH-PERP 81290 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:30:00 in ../database/FTX/15m/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 15m
# DOT-PERP 58843 Candles 15m load since the : 2020-08-21 20:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/DOT-PERP.p
# -> downloding symbol LUNA-PERP for timeframe 15m
# LUNA-PERP 40972 Candles 15m load since the : 2021-02-24 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/LUNA-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 15m
# EGLD-PERP 45556 Candles 15m load since the : 2021-01-07 05:45:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 15m
# AVAX-PERP 54411 Candles 15m load since the : 2020-10-07 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 15m
# XRP-PERP 81291 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 15m
# MANA-PERP 21636 Candles 15m load since the : 2021-09-13 10:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 15m
# XTZ-PERP 81291 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 15m
# WAVES-PERP 51013 Candles 15m load since the : 2020-11-11 09:30:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 15m
# ATOM-PERP 81291 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 15m
# MATIC-PERP 81291 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 15m
# KSM-PERP 43659 Candles 15m load since the : 2021-01-27 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 15m
# LINK-PERP 81291 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 15m
# SHIB-PERP 32908 Candles 15m load since the : 2021-05-19 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 15m
# FTM-PERP 40972 Candles 15m load since the : 2021-02-24 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 15m
# NEAR-PERP 38284 Candles 15m load since the : 2021-03-24 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 15m
# SOL-PERP 59787 Candles 15m load since the : 2020-08-12 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 15m
# THETA-PERP 67210 Candles 15m load since the : 2020-05-26 16:15:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 15m
# CRO-PERP 38243 Candles 15m load since the : 2021-03-24 10:15:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 15m
# FTT-PERP 45940 Candles 15m load since the : 2021-01-03 05:45:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 15m
# RUNE-PERP 61965 Candles 15m load since the : 2020-07-20 07:30:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 15m
# AAVE-PERP 53921 Candles 15m load since the : 2020-10-12 02:30:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 15m
# AXS-PERP 35596 Candles 15m load since the : 2021-04-21 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 15m
# GALA-PERP 14092 Candles 15m load since the : 2021-12-01 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 15m
# SAND-PERP 38284 Candles 15m load since the : 2021-03-24 00:00:00 to : 2022-04-26 18:45:00 in ../database/FTX/15m/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 15m
# NEO-PERP 54412 Candles 15m load since the : 2020-10-07 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 15m
# LTC-PERP 81292 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 15m
# LRC-PERP 38285 Candles 15m load since the : 2021-03-24 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 15m
# CAKE-PERP 38285 Candles 15m load since the : 2021-03-24 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 15m
# XLM-PERP 49036 Candles 15m load since the : 2020-12-02 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 15m
# COMP-PERP 64962 Candles 15m load since the : 2020-06-19 02:30:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 15m
# SLP-PERP 27533 Candles 15m load since the : 2021-07-14 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 15m
# APE-PERP 3341 Candles 15m load since the : 2022-03-23 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 15m
# MTL-PERP 37475 Candles 15m load since the : 2021-04-01 10:30:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 15m
# KAVA-PERP 38285 Candles 15m load since the : 2021-03-24 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 15m
# CRV-PERP 45458 Candles 15m load since the : 2021-01-08 06:30:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 15m
# SNX-PERP 49036 Candles 15m load since the : 2020-12-02 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 15m
# LOOKS-PERP 8717 Candles 15m load since the : 2022-01-26 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 15m
# XMR-PERP 46054 Candles 15m load since the : 2021-01-02 01:30:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 15m
# TRX-PERP 81292 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 15m
# ZRX-PERP 40741 Candles 15m load since the : 2021-02-26 10:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 15m
# PUNDIX-PERP 35597 Candles 15m load since the : 2021-04-21 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 15m
# SUSHI-PERP 57100 Candles 15m load since the : 2020-09-09 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 15m
# BCH-PERP 81292 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 15m
# BNB-PERP 81292 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 15m
# JASMY-PERP 2421 Candles 15m load since the : 2022-04-01 14:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 15m
# ZIL-PERP 40260 Candles 15m load since the : 2021-03-03 10:15:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 15m
# FIL-PERP 53586 Candles 15m load since the : 2020-10-15 14:30:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 15m
# ADA-PERP 81292 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 15m
# ETC-PERP 81292 Candles 15m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:00:00 in ../database/FTX/15m/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 5m
# BTC-PERP 243862 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:15:00 in ../database/FTX/5m/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 5m
# ETH-PERP 243863 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:20:00 in ../database/FTX/5m/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 5m
# DOT-PERP 171293 Candles 5m load since the : 2020-09-09 00:00:00 to : 2022-04-26 19:20:00 in ../database/FTX/5m/DOT-PERP.p
# -> downloding symbol LUNA-PERP for timeframe 5m
# LUNA-PERP 122915 Candles 5m load since the : 2021-02-24 00:00:00 to : 2022-04-26 19:20:00 in ../database/FTX/5m/LUNA-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 5m
# EGLD-PERP 130975 Candles 5m load since the : 2021-01-27 00:00:00 to : 2022-04-26 19:25:00 in ../database/FTX/5m/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 5m
# AVAX-PERP 163230 Candles 5m load since the : 2020-10-07 00:00:00 to : 2022-04-26 19:25:00 in ../database/FTX/5m/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 5m
# XRP-PERP 243864 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:25:00 in ../database/FTX/5m/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 5m
# MANA-PERP 58405 Candles 5m load since the : 2021-10-06 00:00:00 to : 2022-04-26 19:30:00 in ../database/FTX/5m/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 5m
# XTZ-PERP 243865 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:30:00 in ../database/FTX/5m/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 5m
# WAVES-PERP 147104 Candles 5m load since the : 2020-12-02 00:00:00 to : 2022-04-26 19:30:00 in ../database/FTX/5m/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 5m
# ATOM-PERP 243866 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:35:00 in ../database/FTX/5m/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 5m
# MATIC-PERP 243866 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:35:00 in ../database/FTX/5m/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 5m
# KSM-PERP 130978 Candles 5m load since the : 2021-01-27 00:00:00 to : 2022-04-26 19:40:00 in ../database/FTX/5m/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 5m
# LINK-PERP 243867 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 19:40:00 in ../database/FTX/5m/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 5m
# SHIB-PERP 98728 Candles 5m load since the : 2021-05-19 00:00:00 to : 2022-04-26 19:45:00 in ../database/FTX/5m/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 5m
# FTM-PERP 122920 Candles 5m load since the : 2021-02-24 00:00:00 to : 2022-04-26 19:45:00 in ../database/FTX/5m/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 5m
# NEAR-PERP 114856 Candles 5m load since the : 2021-03-24 00:00:00 to : 2022-04-26 19:45:00 in ../database/FTX/5m/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 5m
# SOL-PERP 179362 Candles 5m load since the : 2020-08-12 00:00:00 to : 2022-04-26 19:45:00 in ../database/FTX/5m/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 5m
# THETA-PERP 195487 Candles 5m load since the : 2020-06-17 00:00:00 to : 2022-04-26 19:50:00 in ../database/FTX/5m/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 5m
# CRO-PERP 114733 Candles 5m load since the : 2021-03-24 10:20:00 to : 2022-04-26 19:50:00 in ../database/FTX/5m/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 5m
# FTT-PERP 130980 Candles 5m load since the : 2021-01-27 00:00:00 to : 2022-04-26 19:50:00 in ../database/FTX/5m/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 5m
# RUNE-PERP 179364 Candles 5m load since the : 2020-08-12 00:00:00 to : 2022-04-26 19:55:00 in ../database/FTX/5m/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 5m
# AAVE-PERP 155173 Candles 5m load since the : 2020-11-04 00:00:00 to : 2022-04-26 19:55:00 in ../database/FTX/5m/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 5m
# AXS-PERP 106794 Candles 5m load since the : 2021-04-21 00:00:00 to : 2022-04-26 19:55:00 in ../database/FTX/5m/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 5m
# GALA-PERP 42283 Candles 5m load since the : 2021-12-01 00:00:00 to : 2022-04-26 20:00:00 in ../database/FTX/5m/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 5m
# SAND-PERP 114859 Candles 5m load since the : 2021-03-24 00:00:00 to : 2022-04-26 20:00:00 in ../database/FTX/5m/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 5m
# NEO-PERP 163237 Candles 5m load since the : 2020-10-07 00:00:00 to : 2022-04-26 20:00:00 in ../database/FTX/5m/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 5m
# LTC-PERP 243872 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 20:05:00 in ../database/FTX/5m/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 5m
# LRC-PERP 114860 Candles 5m load since the : 2021-03-24 00:00:00 to : 2022-04-26 20:05:00 in ../database/FTX/5m/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 5m
# CAKE-PERP 114860 Candles 5m load since the : 2021-03-24 00:00:00 to : 2022-04-26 20:05:00 in ../database/FTX/5m/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 5m
# XLM-PERP 147112 Candles 5m load since the : 2020-12-02 00:00:00 to : 2022-04-26 20:10:00 in ../database/FTX/5m/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 5m
# COMP-PERP 194885 Candles 5m load since the : 2020-06-19 02:30:00 to : 2022-04-26 20:10:00 in ../database/FTX/5m/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 5m
# SLP-PERP 82605 Candles 5m load since the : 2021-07-14 00:00:00 to : 2022-04-26 20:10:00 in ../database/FTX/5m/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 5m
# APE-PERP 10035 Candles 5m load since the : 2022-03-23 00:00:00 to : 2022-04-26 20:10:00 in ../database/FTX/5m/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 5m
# MTL-PERP 106798 Candles 5m load since the : 2021-04-21 00:00:00 to : 2022-04-26 20:15:00 in ../database/FTX/5m/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 5m
# KAVA-PERP 114862 Candles 5m load since the : 2021-03-24 00:00:00 to : 2022-04-26 20:15:00 in ../database/FTX/5m/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 5m
# CRV-PERP 130985 Candles 5m load since the : 2021-01-27 00:00:00 to : 2022-04-26 20:15:00 in ../database/FTX/5m/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 5m
# SNX-PERP 147114 Candles 5m load since the : 2020-12-02 00:00:00 to : 2022-04-26 20:20:00 in ../database/FTX/5m/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 5m
# LOOKS-PERP 26164 Candles 5m load since the : 2022-01-26 00:00:00 to : 2022-04-26 20:20:00 in ../database/FTX/5m/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 5m
# XMR-PERP 138168 Candles 5m load since the : 2021-01-02 01:30:00 to : 2022-04-26 20:20:00 in ../database/FTX/5m/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 5m
# TRX-PERP 243876 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 20:25:00 in ../database/FTX/5m/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 5m
# ZRX-PERP 122232 Candles 5m load since the : 2021-02-26 10:00:00 to : 2022-04-26 20:25:00 in ../database/FTX/5m/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 5m
# PUNDIX-PERP 106800 Candles 5m load since the : 2021-04-21 00:00:00 to : 2022-04-26 20:25:00 in ../database/FTX/5m/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 5m
# SUSHI-PERP 171306 Candles 5m load since the : 2020-09-09 00:00:00 to : 2022-04-26 20:25:00 in ../database/FTX/5m/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 5m
# BCH-PERP 243876 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 20:30:00 in ../database/FTX/5m/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 5m
# BNB-PERP 243877 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 20:30:00 in ../database/FTX/5m/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 5m
# JASMY-PERP 1976 Candles 5m load since the : 2022-04-20 00:00:00 to : 2022-04-26 20:35:00 in ../database/FTX/5m/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 5m
# ZIL-PERP 114866 Candles 5m load since the : 2021-03-24 00:00:00 to : 2022-04-26 20:35:00 in ../database/FTX/5m/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 5m
# FIL-PERP 155181 Candles 5m load since the : 2020-11-04 00:00:00 to : 2022-04-26 20:35:00 in ../database/FTX/5m/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 5m
# ADA-PERP 243879 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 20:40:00 in ../database/FTX/5m/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 5m
# ETC-PERP 243879 Candles 5m load since the : 2020-01-01 00:00:00 to : 2022-04-26 20:40:00 in ../database/FTX/5m/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 3m
# Error empty dataframe on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 3m
# Error empty dataframe on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 3m
# Error empty dataframe on DOT-PERP
# -> downloding symbol LUNA-PERP for timeframe 3m
# Error empty dataframe on LUNA-PERP
# -> downloding symbol EGLD-PERP for timeframe 3m
# Error empty dataframe on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 3m
# Error empty dataframe on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 3m
# Error empty dataframe on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 3m
# Error empty dataframe on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 3m
# Error empty dataframe on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 3m
# Error empty dataframe on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 3m
# Error empty dataframe on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 3m
# Error empty dataframe on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 3m
# Error empty dataframe on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 3m
# Error empty dataframe on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 3m
# Error empty dataframe on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 3m
# Error empty dataframe on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 3m
# Error empty dataframe on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 3m
# Error empty dataframe on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 3m
# Error empty dataframe on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 3m
# Error empty dataframe on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 3m
# Error empty dataframe on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 3m
# Error empty dataframe on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 3m
# Error empty dataframe on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 3m
# Error empty dataframe on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 3m
# Error empty dataframe on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 3m
# Error empty dataframe on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 3m
# Error empty dataframe on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 3m
# Error empty dataframe on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 3m
# Error empty dataframe on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 3m
# Error empty dataframe on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 3m
# Error empty dataframe on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 3m
# Error empty dataframe on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 3m
# Error empty dataframe on SLP-PERP
# -> downloding symbol APE-PERP for timeframe 3m
# Error empty dataframe on APE-PERP
# -> downloding symbol MTL-PERP for timeframe 3m
# Error empty dataframe on MTL-PERP
# -> downloding symbol KAVA-PERP for timeframe 3m
# Error empty dataframe on KAVA-PERP
# -> downloding symbol CRV-PERP for timeframe 3m
# Error empty dataframe on CRV-PERP
# -> downloding symbol SNX-PERP for timeframe 3m
# Error empty dataframe on SNX-PERP
# -> downloding symbol LOOKS-PERP for timeframe 3m
# Error empty dataframe on LOOKS-PERP
# -> downloding symbol XMR-PERP for timeframe 3m
# Error empty dataframe on XMR-PERP
# -> downloding symbol TRX-PERP for timeframe 3m
# Error empty dataframe on TRX-PERP
# -> downloding symbol ZRX-PERP for timeframe 3m
# Error empty dataframe on ZRX-PERP
# -> downloding symbol PUNDIX-PERP for timeframe 3m
# Error empty dataframe on PUNDIX-PERP
# -> downloding symbol SUSHI-PERP for timeframe 3m
# Error empty dataframe on SUSHI-PERP
# -> downloding symbol BCH-PERP for timeframe 3m
# Error empty dataframe on BCH-PERP
# -> downloding symbol BNB-PERP for timeframe 3m
# Error empty dataframe on BNB-PERP
# -> downloding symbol JASMY-PERP for timeframe 3m
# Error empty dataframe on JASMY-PERP
# -> downloding symbol ZIL-PERP for timeframe 3m
# Error empty dataframe on ZIL-PERP
# -> downloding symbol FIL-PERP for timeframe 3m
# Error empty dataframe on FIL-PERP
# -> downloding symbol ADA-PERP for timeframe 3m
# Error empty dataframe on ADA-PERP
# -> downloding symbol ETC-PERP for timeframe 3m
# Error empty dataframe on ETC-PERP
# -> downloding symbol BTC-PERP for timeframe 1m
# Error on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 1m
# Error on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 1m
# Error on DOT-PERP
# -> downloding symbol LUNA-PERP for timeframe 1m
# Error on LUNA-PERP
# -> downloding symbol EGLD-PERP for timeframe 1m
# Error on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 1m
# Error on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 1m
# Error on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 1m
# Error on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 1m
# Error on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 1m
# Error on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 1m
# Error on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 1m
# Error on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 1m
# Error on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 1m
# Error on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 1m
# Error on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 1m
# Error on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 1m
# Error on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 1m
# Error on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 1m
# Error on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 1m
# Error on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 1m
# Error on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 1m
# Error on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 1m
# Error on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 1m
# Error on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 1m
# Error on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 1m
# Error on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 1m
# Error on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 1m
# Error on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 1m
# Error on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 1m
# Error on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 1m
# Error on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 1m
# Error on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 1m
# Error on SLP-PERP
# -> downloding symbol APE-PERP for timeframe 1m
# Error on APE-PERP
# -> downloding symbol MTL-PERP for timeframe 1m
# Error on MTL-PERP
# -> downloding symbol KAVA-PERP for timeframe 1m
# Error on KAVA-PERP
# -> downloding symbol CRV-PERP for timeframe 1m
# Error on CRV-PERP
# -> downloding symbol SNX-PERP for timeframe 1m
# Error on SNX-PERP
# -> downloding symbol LOOKS-PERP for timeframe 1m
# Error on LOOKS-PERP
# -> downloding symbol XMR-PERP for timeframe 1m
# Error on XMR-PERP
# -> downloding symbol TRX-PERP for timeframe 1m
# Error on TRX-PERP
# -> downloding symbol ZRX-PERP for timeframe 1m
# Error on ZRX-PERP
# -> downloding symbol PUNDIX-PERP for timeframe 1m
# Error on PUNDIX-PERP
# -> downloding symbol SUSHI-PERP for timeframe 1m
# Error on SUSHI-PERP
# -> downloding symbol BCH-PERP for timeframe 1m
# Error on BCH-PERP
# -> downloding symbol BNB-PERP for timeframe 1m
# Error on BNB-PERP
# -> downloding symbol JASMY-PERP for timeframe 1m
# Error on JASMY-PERP
# -> downloding symbol ZIL-PERP for timeframe 1m
# Error on ZIL-PERP
# -> downloding symbol FIL-PERP for timeframe 1m
# Error on FIL-PERP
# -> downloding symbol ADA-PERP for timeframe 1m
# Error on ADA-PERP
# -> downloding symbol ETC-PERP for timeframe 1m
# Error on ETC-PERP

# %% [markdown]
# <h1>Update data from local database with new data from api</h1>

# %%
# -- Data variable --
pair_symbols = pair_json['TopperfFTX']
#pair_symbols = ['BNB/USDT']
timeframes = ['1h']

# -- Instance class --
dataEngine = DataEngine(session=ccxt.binance())

# -- Download data from data variable --
dataEngine.update_data(pair_symbols, timeframes)
# Out:
# Error on BTC-PERP 1h
# Error on ETH-PERP 1h
# Error on DOT-PERP 1h
# Error on LUNA-PERP 1h
# Error on EGLD-PERP 1h
# Error on AVAX-PERP 1h
# Error on XRP-PERP 1h
# Error on MANA-PERP 1h
# Error on XTZ-PERP 1h
# Error on WAVES-PERP 1h
# Error on ATOM-PERP 1h
# Error on MATIC-PERP 1h
# Error on KSM-PERP 1h
# Error on LINK-PERP 1h
# Error on SHIB-PERP 1h
# Error on FTM-PERP 1h
# Error on NEAR-PERP 1h
# Error on SOL-PERP 1h
# Error on HBAR-PERP 1h
# Error on THETA-PERP 1h
# Error on CRO-PERP 1h
# Error on LEO-PERP 1h
# Error on HT-PERP 1h
# Error on FTT-PERP 1h
# Error on ROSE-PERP 1h
# Error on RUNE-PERP 1h
# Error on AAVE-PERP 1h
# Error on AXS-PERP 1h
# Error on GALA-PERP 1h
# Error on SAND-PERP 1h
# Error on DASH-PERP 1h
# Error on NEO-PERP 1h
# Error on LTC-PERP 1h
# Error on EOS-PERP 1h
# Error on LRC-PERP 1h
# Error on CAKE-PERP 1h
# Error on ADA-PERP 1h
# Error on BNB-PERP 1h
# Error on XLM-PERP 1h
# Error on XEM-PERP 1h
# Error on COMP-PERP 1h
# Error on AUDIO-PERP 1h
# Error on SLP-PERP 1h
# Error on APE-PERP 1h
